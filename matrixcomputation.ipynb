# %%
import numpy as np
A=np.array([[1,3,4],[6,4,1],[2,2,2]])

# %%
A
# Out:
# array([[1, 3, 4],
#        [6, 4, 1],
#        [2, 2, 2]])

# %%
B=np.array([5,16,11])

# %%
B
# Out:
# array([ 5, 16, 11])

# %%
A_inv=np.linalg.inv(A)
A_inv
# Out:
# array([[-0.75 , -0.25 ,  1.625],
#        [ 1.25 ,  0.75 , -2.875],
#        [-0.5  , -0.5  ,  1.75 ]])

# %%
np.dot(A_inv,B)
# Out:
# array([ 10.125, -13.375,   8.75 ])
